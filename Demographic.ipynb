# %%
import pandas as pd
order_details = pd.read_excel(r"C:\Users\91789\\Downloads\\order_details.xlsx")
order_details
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 2       1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 7       1008    U003 2024-12-04      Lunch    Veggie Burger     Canceled
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# ...

# %%
order_details.isnull().sum()
# Out:
# Order ID        0
# User ID         0
# Order Date      0
# Meal Type       0
# Dish Name       0
# Order Status    0
# Amount (USD)    0
# Time of Day     0
# Rating          2
# Session ID      0
# dtype: int64

# %%
order_details.dropna()
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# 12      1013    U005 2024-12-07      Lunch     Caesar Salad    Completed
# 13      1014    U006 2024-12-07     Dinner  Grilled Chicken    Completed
# ...

# %%
cooking_sessions=pd.read_excel(r"C:\Users\91789\\Downloads\\cooking_sessions.xlsx")
cooking_sessions
# Out:
#    Session ID User ID        Dish Name  Meal Type       Session Start  \
# 0        S001    U001        Spaghetti     Dinner 2024-12-01 19:00:00
# 1        S002    U002     Caesar Salad      Lunch 2024-12-01 12:00:00
# 2        S003    U003  Grilled Chicken     Dinner 2024-12-02 19:30:00
# 3        S004    U001         Pancakes  Breakfast 2024-12-02 07:30:00
# 4        S005    U004     Caesar Salad      Lunch 2024-12-03 13:00:00
# 5        S006    U002        Spaghetti     Dinner 2024-12-03 18:30:00
# 6        S007    U005  Grilled Chicken     Dinner 2024-12-04 18:00:00
# 7        S008    U003    Veggie Burger      Lunch 2024-12-04 13:30:00
# 8        S009    U001  Grilled Chicken     Dinner 2024-12-05 19:00:00
# 9        S010    U002          Oatmeal  Breakfast 2024-12-05 07:00:00
# 10       S011    U003         Pancakes  Breakfast 2024-12-06 08:00:00
# 11       S012    U004        Spaghetti     Dinner 2024-12-06 19:00:00
# ...

# %%
cooking_sessions.isnull().sum()
# Out:
# Session ID         0
# User ID            0
# Dish Name          0
# Meal Type          0
# Session Start      0
# Session End        0
# Duration (mins)    0
# Session Rating     0
# dtype: int64

# %%
cooking_sessions.drop_duplicates()
# Out:
#    Session ID User ID        Dish Name  Meal Type       Session Start  \
# 0        S001    U001        Spaghetti     Dinner 2024-12-01 19:00:00
# 1        S002    U002     Caesar Salad      Lunch 2024-12-01 12:00:00
# 2        S003    U003  Grilled Chicken     Dinner 2024-12-02 19:30:00
# 3        S004    U001         Pancakes  Breakfast 2024-12-02 07:30:00
# 4        S005    U004     Caesar Salad      Lunch 2024-12-03 13:00:00
# 5        S006    U002        Spaghetti     Dinner 2024-12-03 18:30:00
# 6        S007    U005  Grilled Chicken     Dinner 2024-12-04 18:00:00
# 7        S008    U003    Veggie Burger      Lunch 2024-12-04 13:30:00
# 8        S009    U001  Grilled Chicken     Dinner 2024-12-05 19:00:00
# 9        S010    U002          Oatmeal  Breakfast 2024-12-05 07:00:00
# 10       S011    U003         Pancakes  Breakfast 2024-12-06 08:00:00
# 11       S012    U004        Spaghetti     Dinner 2024-12-06 19:00:00
# ...

# %%
user_details=pd.read_excel(r"C:\Users\91789\\Downloads\\user_details.xlsx")
user_details
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
# 8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
# 9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# ...

# %%
user_details.isnull().sum()
# Out:
# User ID              0
# User Name            0
# Age                  0
# Location             0
# Registration Date    0
# Phone                0
# Email                0
# Favorite Meal        0
# Total Orders         0
# dtype: int64

# %%
user_details.drop_duplicates()
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
# 8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
# 9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# ...

# %%
merged_data = pd.merge(cooking_sessions, order_details, on="User ID", how="inner")
merged_data
# Out:
#    Session ID_x User ID      Dish Name_x Meal Type_x       Session Start  \
# 0          S001    U001        Spaghetti      Dinner 2024-12-01 19:00:00
# 1          S001    U001        Spaghetti      Dinner 2024-12-01 19:00:00
# 2          S001    U001        Spaghetti      Dinner 2024-12-01 19:00:00
# 3          S004    U001         Pancakes   Breakfast 2024-12-02 07:30:00
# 4          S004    U001         Pancakes   Breakfast 2024-12-02 07:30:00
# 5          S004    U001         Pancakes   Breakfast 2024-12-02 07:30:00
# 6          S009    U001  Grilled Chicken      Dinner 2024-12-05 19:00:00
# 7          S009    U001  Grilled Chicken      Dinner 2024-12-05 19:00:00
# 8          S009    U001  Grilled Chicken      Dinner 2024-12-05 19:00:00
# 9          S002    U002     Caesar Salad       Lunch 2024-12-01 12:00:00
# 10         S002    U002     Caesar Salad       Lunch 2024-12-01 12:00:00
# 11         S002    U002     Caesar Salad       Lunch 2024-12-01 12:00:00
# ...

# %%
final_data = pd.merge(merged_data, user_details, on="User ID", how="inner")
final_data
# Out:
#    Session ID_x User ID      Dish Name_x Meal Type_x       Session Start  \
# 0          S001    U001        Spaghetti      Dinner 2024-12-01 19:00:00
# 1          S001    U001        Spaghetti      Dinner 2024-12-01 19:00:00
# 2          S001    U001        Spaghetti      Dinner 2024-12-01 19:00:00
# 3          S004    U001         Pancakes   Breakfast 2024-12-02 07:30:00
# 4          S004    U001         Pancakes   Breakfast 2024-12-02 07:30:00
# 5          S004    U001         Pancakes   Breakfast 2024-12-02 07:30:00
# 6          S009    U001  Grilled Chicken      Dinner 2024-12-05 19:00:00
# 7          S009    U001  Grilled Chicken      Dinner 2024-12-05 19:00:00
# 8          S009    U001  Grilled Chicken      Dinner 2024-12-05 19:00:00
# 9          S002    U002     Caesar Salad       Lunch 2024-12-01 12:00:00
# 10         S002    U002     Caesar Salad       Lunch 2024-12-01 12:00:00
# 11         S002    U002     Caesar Salad       Lunch 2024-12-01 12:00:00
# ...

# %%
popular_dishes = order_details['Dish Name'].value_counts().head(10)
popular_dishes
# Out:
# Dish Name
# Spaghetti          4
# Grilled Chicken    4
# Caesar Salad       3
# Pancakes           2
# Veggie Burger      2
# Oatmeal            1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
popular_dishes.plot(kind='bar',color='red',figsize=(10,5))
plt.title("Top Dishes")
plt.xlabel("Dish Name")
plt.ylabel("Number of Orders")
plt.show()

# %%
location=final_data['Location'].value_counts()
location
# Out:
# Location
# New York         9
# Los Angeles      9
# Chicago          9
# San Francisco    4
# Seattle          4
# Austin           1
# Boston           1
# Miami            1
# Name: count, dtype: int64

# %%
Spaghetti_max=final_data[final_data['Dish Name_x']=='Spaghetti']
Spaghetti_max
# Out:
#    Session ID_x User ID Dish Name_x Meal Type_x       Session Start  \
# 0          S001    U001   Spaghetti      Dinner 2024-12-01 19:00:00
# 1          S001    U001   Spaghetti      Dinner 2024-12-01 19:00:00
# 2          S001    U001   Spaghetti      Dinner 2024-12-01 19:00:00
# 12         S006    U002   Spaghetti      Dinner 2024-12-03 18:30:00
# 13         S006    U002   Spaghetti      Dinner 2024-12-03 18:30:00
# 14         S006    U002   Spaghetti      Dinner 2024-12-03 18:30:00
# 29         S012    U004   Spaghetti      Dinner 2024-12-06 19:00:00
# 30         S012    U004   Spaghetti      Dinner 2024-12-06 19:00:00
# 36         S015    U007   Spaghetti      Dinner 2024-12-08 19:30:00
#
#            Session End  Duration (mins)  Session Rating  Order ID Order Date  \
# 0  2024-12-01 19:30:00               30             4.5      1001 2024-12-01
# 1  2024-12-01 19:30:00               30             4.5      1004 2024-12-02
# ...

# %%
location_counts = Spaghetti_max['Location'].value_counts()
location_counts
# Out:
# Location
# New York         3
# Los Angeles      3
# San Francisco    2
# Boston           1
# Name: count, dtype: int64

# %%
age_order_counts=final_data.groupby('Age')['Order ID'].count()
age_order_counts
#grouping by age and counting no of orders
# Out:
# Age
# 25    1
# 27    4
# 28    9
# 30    4
# 31    1
# 35    9
# 38    1
# 42    9
# Name: Order ID, dtype: int64

# %%
import matplotlib.pyplot as plt
age_order_counts.plot(kind='ba',color='green',figsize=(10,10))
plt.title('Orders by Age')
plt.xlabel('Age')
plt.ylabel('Number of Orders')
plt.show()

# %%
combined_analysis = final_data.groupby(['Age','Location'])['Order ID'].count().reset_index()

combined_analysis = combined_analysis.sort_values(['Age','Location'])

print("Combined Analysis:")
print(combined_analysis)
# Out:
# Combined Analysis:
#    Age       Location  Order ID
# 0   25         Austin         1
# 1   27  San Francisco         4
# 2   28       New York         9
# 3   30        Seattle         4
# 4   31          Miami         1
# 5   35    Los Angeles         9
# 6   38         Boston         1
# 7   42        Chicago         9

# %%
#Heatmap: Combined analysis of multiple demographics.
combined_pivot = combined_analysis.pivot_table(values='Order ID', index=['Age'], columns=['Location'], fill_value=0)

import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(combined_pivot, annot=True,cmap="coolwarm")
plt.title("Orders by Age,Location")
plt.xlabel("Location")
plt.ylabel("Age")
plt.show()

# %%
session_order_analysis=final_data.groupby('Session ID_x')['Order ID'].count()
session_order_analysis
# Out:
# Session ID_x
# S001    3
# S002    3
# S003    3
# S004    3
# S005    2
# S006    3
# S007    2
# S008    3
# S009    3
# S010    3
# S011    3
# S012    2
# S013    2
# S014    1
# S015    1
# S016    1
# Name: Order ID, dtype: int64

# %%
print("Average orders per session:", session_order_analysis.mean())

import seaborn as sns

sns.scatterplot(data=final_data, x='Duration (mins)', y='Amount (USD)')
plt.title("Session Duration vs. Order Amount")
plt.xlabel("Session Duration (mins)")
plt.ylabel("Order Amount ($)")
plt.show()
# Out:
# Average orders per session: 2.375
